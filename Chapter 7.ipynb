# %% [markdown]
# # Chapter 7: Manage business metrics

# %%
import numpy as np
import scipy
import scipy.stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import tuningup

# %%
mpl.rcParams['figure.dpi']= 300
tu = tuningup.TuningUp(chapter=7)

# %% [markdown]
# ## 7.1 Focus on the business

# %% [markdown]
# ### 7.1.1	Don’t evaluate a model

# %%
prediction_quality = np.linspace(0,4,10)
dau = 1-np.exp(-prediction_quality)
dau[-2] = dau[-1]
plt.plot(prediction_quality, dau, 'o', color=tu.clr1);
plt.xlabel('prediction quality')
plt.ylabel('DAU')
plt.xticks([])
plt.yticks([])
tu.save_fig(1)
